# %%
# Out:
# --- Cleaning /kaggle/input/datasets/ananyassssss/rvudata/device.csv ---
# Original shape: (65668, 5)
# Missing values per column:
# Series([], dtype: int64)
# Shape after dropping missing values: (65668, 5)
# Removed 0 duplicate rows
# Final shape: (65668, 5)
# ['id', 'date', 'user', 'pc', 'activity']
#
# --- Cleaning /kaggle/input/datasets/ananyassssss/rvudata/http.csv ---
# Original shape: (3451664, 5)
# Missing values per column:
# Series([], dtype: int64)
# Shape after dropping missing values: (3451664, 5)
# Removed 0 duplicate rows
# Final shape: (3451664, 5)
# ['id', 'date', 'user', 'pc', 'activity']
#
# --- Cleaning /kaggle/input/datasets/ananyassssss/rvudata/logon.csv ---
# Original shape: (849579, 5)
# Missing values per column:
# Series([], dtype: int64)
# Shape after dropping missing values: (849579, 5)
# Removed 0 duplicate rows
# Final shape: (849579, 5)
# ['id', 'date', 'user', 'pc', 'activity']
# ...

# %%
# Out:
#                          id                date          user       pc  \
# 0  {A6N9-D5VK97CX-7245PVFQ} 2010-01-04 07:37:50  DTAA/AAA0371  PC-1689
# 1  {E1O1-B3RP45AB-7775STQS} 2010-01-04 12:43:44  DTAA/AAA0371  PC-1689
# 2  {A3U1-F3GA48SC-7481SKGQ} 2010-01-04 13:37:47  DTAA/AAA0371  PC-1689
# 3  {J9X3-S3OW78LE-2398HAKZ} 2010-01-04 14:44:45  DTAA/AAA0371  PC-1689
# 4  {G4P3-P7LC16EB-8242LSLL} 2010-01-05 07:51:57  DTAA/AAA0371  PC-1689
#
#              activity source
# 0               Logon  logon
# 1               Logon  logon
# 2  http://espn.go.com   http
# 3              Logoff  logon
# 4               Logon  logon

# %%
# Out:
# Daily indicators shape: (334905, 6)
#             user         day  unique_pc_count  login_count  \
# 0   DTAA/AAA0371  2010-01-04                1            3
# 1   DTAA/AAA0371  2010-01-05                1            3
# 2   DTAA/AAA0371  2010-01-06                1            3
# 3   DTAA/AAA0371  2010-01-07                1            2
# 4   DTAA/AAA0371  2010-01-08                1            3
# 5   DTAA/AAA0371  2010-01-11                1            3
# 6   DTAA/AAA0371  2010-01-12                1            3
# 7   DTAA/AAA0371  2010-01-13                1            3
# 8   DTAA/AAA0371  2010-01-14                1            3
# 9   DTAA/AAA0371  2010-01-15                1            3
# 10  DTAA/AAA0371  2010-01-18                1            3
# 11  DTAA/AAA0371  2010-01-19                1            2
# 12  DTAA/AAA0371  2010-01-20                1            3
# 13  DTAA/AAA0371  2010-01-21                1            3
# ...

# %%
# Out:
# Number of user profiles: 1000
#            user  login_count_mean  login_count_std  device_event_count_mean  \
# 0  DTAA/AAA0371          2.906897         0.640302                 0.000000
# 1  DTAA/AAC0344          2.000000         0.000000                 0.000000
# 2  DTAA/AAC0599          2.000000         0.000000                 0.000000
# 3  DTAA/AAH0734          2.000000         0.000000                 0.000000
# 4  DTAA/AAK0658          2.000000         0.000000                 0.000000
# 5  DTAA/AAK0924          2.000000         0.000000                 0.000000
# 6  DTAA/AAR0508          2.000000         0.000000                 0.000000
# 7  DTAA/AAS0709          2.910145         0.610505                 0.000000
# 8  DTAA/ABB0272          3.463768         1.019857                 1.898551
# 9  DTAA/ABD0833          2.000000         0.000000                 0.000000
#
#    device_event_count_std  http_event_count_mean  http_event_count_std  \
# ...
