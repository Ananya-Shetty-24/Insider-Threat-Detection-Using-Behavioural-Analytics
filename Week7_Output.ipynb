# %%
# Out:
# --- Challenge 6: Precision, Recall, F1 ---
#
# Isolation Forest:
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.95      0.98    334905
#       Threat       0.03      1.00      0.06       500
#
#     accuracy                           0.95    335405
#    macro avg       0.51      0.98      0.52    335405
# weighted avg       1.00      0.95      0.97    335405
#
# One-Class SVM:
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.95      0.97    334905
#       Threat       0.03      1.00      0.06       500
#
#     accuracy                           0.95    335405
#    macro avg       0.51      0.98      0.52    335405
# weighted avg       1.00      0.95      0.97    335405
#
# Autoencoder:
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.95      0.98    334905
#       Threat       0.03      1.00      0.06       500
#
# ...
