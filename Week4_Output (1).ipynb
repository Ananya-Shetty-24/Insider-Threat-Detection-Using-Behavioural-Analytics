# %%
# Out:
# --- Model 1: Isolation Forest ---
# Anomalous user-days: 16746 (5.0%)
#
# --- Model 2: One-Class SVM ---
# Anomalous user-days: 17484 (5.2%)
#
# --- Model 3: Autoencoder ---
# Threshold: 0.0385
# Anomalous user-days: 16746 (5.0%)
#
# --- Model 4: DBSCAN ---
# PCA variance retained: 0.866
# /tmp/ipykernel_3709/3908170494.py:118: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.sample(min(len(g), 15), random_state=42))
# Clusters found: 31
# Anomalous user-days: 3569 (1.1%)
#
# --- Alert Generation ---
# Flag count distribution:
# model_flag_count
# 0    303795
# 1     16617
# 2      7545
# 3      4954
# 4      1994
# Name: count, dtype: int64
#
# Total alerts (>=2 models): 14493
#
# ...

# %%
# Out:
# Saved insider_threat_scores.csv: (334905, 18)
# Saved insider_threat_alerts.csv: (14493, 8)
# Saved insider_threat_user_summary.csv: (735, 3)
