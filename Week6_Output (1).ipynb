# %%
# Out:
# --- Challenge 1: Simulating Data Exfiltration ---
# Generated 200 exfiltration scenarios
#        login_count  device_event_count  http_event_count  unique_pc_count  \
# count    200.00000          200.000000        200.000000            200.0
# mean       1.50500            3.440000        547.665000              1.0
# std        0.50123            1.105673        137.272032              0.0
# min        1.00000            2.000000        301.000000              1.0
# 25%        1.00000            2.000000        435.750000              1.0
# 50%        2.00000            3.000000        540.500000              1.0
# 75%        2.00000            4.000000        672.250000              1.0
# max        2.00000            5.000000        797.000000              1.0
#
#        after_hours_count  is_weekend  first_login_hour  last_activity_hour
# count         200.000000  200.000000        200.000000          200.000000
# ...

# %%
# Out:
# --- Challenge 1: Simulating Data Exfiltration ---
# Generated 200 exfiltration scenarios
#        login_count  device_event_count  http_event_count  unique_pc_count  \
# count    200.00000          200.000000        200.000000            200.0
# mean       1.50500            3.440000        547.665000              1.0
# std        0.50123            1.105673        137.272032              0.0
# min        1.00000            2.000000        301.000000              1.0
# 25%        1.00000            2.000000        435.750000              1.0
# 50%        2.00000            3.000000        540.500000              1.0
# 75%        2.00000            4.000000        672.250000              1.0
# max        2.00000            5.000000        797.000000              1.0
#
#        after_hours_count  is_weekend  first_login_hour  last_activity_hour
# count         200.000000  200.000000        200.000000          200.000000
# ...

# %%
# Out:
# --- Challenge 6a: Simulating SUBTLE Data Exfiltration ---
# Generated 200 subtle exfiltration scenarios
#        login_count  device_event_count  http_event_count  unique_pc_count  \
# count   200.000000          200.000000        200.000000            200.0
# mean      1.460000            1.470000         22.635000              1.0
# std       0.499648            0.500352         23.933362              0.0
# min       1.000000            1.000000          2.000000              1.0
# 25%       1.000000            1.000000         11.000000              1.0
# 50%       1.000000            1.000000         14.000000              1.0
# 75%       2.000000            2.000000         17.000000              1.0
# max       2.000000            2.000000        108.000000              1.0
#
#        after_hours_count  is_weekend  first_login_hour  last_activity_hour
# count         200.000000  200.000000        200.000000            200.0000
# ...
